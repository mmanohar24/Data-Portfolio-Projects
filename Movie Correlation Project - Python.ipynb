# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# Now we need to read in the data
df = pd.read_csv(r"/Users/manojvenkatesunmanoharan/Desktop/Certification/Python/Projects/movies.csv")

# %%
# Let's look at the data

df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
# Let's see if there is any missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# Dropping any rows with empty values.
df2 = df.dropna()
df2.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
# Running again to check if there are any empty records.
for col in df.columns:
    pct_missing = np.mean(df2[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# Find datatypes for columns
df2.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Changing datatype of column
df2['budget'] = df2['budget'].astype('int64')
df2['gross'] = df2['gross'].astype('int64')

# %%
df2[ ["Date", 'Year']] = df2["released"].str.split(',', n=2, expand = True)
df2.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
# Creating exact realease year 
df2['released_year'] = df2['Year'].astype(str).str[:5]
df2.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
# Remove columns that are not usefull
df2 = df2.drop(columns = ['Date', 'Year'])
df2.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
df2.sort_values(by = ['gross'], inplace = False, ascending = False).head(10)
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
# 7480  4388       4      2  2019      1126    6.9   222000.0      1012    1361
# 6653  2117       5      0  2015      1303    7.0   593000.0       335    2523
# 6043  3878       5      0  2012      1899    8.0  1300000.0      1060    1646
# 6646  1541       5      0  2015       165    7.1   370000.0       809     481
# 7494  1530       4      2  2019      2053    6.8   148000.0       277    1383
#
#       star  country     budget       gross  company  runtime  released_year
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
# Drop duplicates

df2 = df2.drop_duplicates()
df2.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
# Scatter plot with budget vs gross

plt.scatter(x = df2['budget'], y = df2['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
# Plot budget vs gross using seaborn

# import seaborn as sns
sns.regplot(x = 'budget', y = 'gross', data = df2, scatter_kws = {"color": "red"}, line_kws = {"color": "blue"})
plt.show()

# %%
# Let's look at the correlation
# Correlation Method types = pearson, kendall, spearman

df_corr = df2[['budget', 'gross', 'runtime', 'score', 'votes', 'year']].corr()
df_corr
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.740247  0.318695  0.072001  0.439675  0.327722
# gross    0.740247  1.000000  0.275796  0.222556  0.614751  0.274321
# runtime  0.318695  0.275796  1.000000  0.414068  0.352303  0.075077
# score    0.072001  0.222556  0.414068  1.000000  0.474256  0.056386
# votes    0.439675  0.614751  0.352303  0.474256  1.000000  0.206021
# year     0.327722  0.274321  0.075077  0.056386  0.206021  1.000000

# %%
# Pearson Method
df_corr_p = df2[['budget', 'gross', 'runtime', 'score', 'votes', 'year']].corr(method = "pearson")
df_corr_p
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.740247  0.318695  0.072001  0.439675  0.327722
# gross    0.740247  1.000000  0.275796  0.222556  0.614751  0.274321
# runtime  0.318695  0.275796  1.000000  0.414068  0.352303  0.075077
# score    0.072001  0.222556  0.414068  1.000000  0.474256  0.056386
# votes    0.439675  0.614751  0.352303  0.474256  1.000000  0.206021
# year     0.327722  0.274321  0.075077  0.056386  0.206021  1.000000

# %%
# Kendall method
df_corr_k = df2[['budget', 'gross', 'runtime', 'score', 'votes', 'year']].corr(method = "kendall")
df_corr_k
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.512057  0.231278 -0.006406  0.346274  0.220833
# gross    0.512057  1.000000  0.176979  0.124943  0.553625  0.239539
# runtime  0.231278  0.176979  1.000000  0.292254  0.205344  0.064824
# score   -0.006406  0.124943  0.292254  1.000000  0.350185  0.039389
# votes    0.346274  0.553625  0.205344  0.350185  1.000000  0.296512
# year     0.220833  0.239539  0.064824  0.039389  0.296512  1.000000

# %%
# Spearman method
df_corr_s = df2[['budget', 'gross', 'runtime', 'score', 'votes', 'year']].corr(method = "spearman")
df_corr_s
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.692958  0.330794 -0.009971  0.493461  0.312886
# gross    0.692958  1.000000  0.257400  0.183192  0.745793  0.351045
# runtime  0.330794  0.257400  1.000000  0.412155  0.300621  0.095444
# score   -0.009971  0.183192  0.412155  1.000000  0.495409  0.057741
# votes    0.493461  0.745793  0.300621  0.495409  1.000000  0.427623
# year     0.312886  0.351045  0.095444  0.057741  0.427623  1.000000

# %%
# High correlation matrix between budget vs gross

sns.heatmap(df_corr_p, annot = True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# Company Information

df2.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
df_copy = df2
df_copy.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
df2_numerized = df2

for col_name in df2_numerized.columns:
    if(df2_numerized[col_name].dtype == 'object'):
        df2_numerized[col_name] = df2_numerized[col_name].astype('category')
        df2_numerized[col_name]= df2_numerized[col_name].cat.codes


df2_numerized.head(10)
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
# 5  1509       6      9  1980      1922    6.4   123000.0      1758    3081
# 6  3930       6      0  1980      1359    7.9   188000.0       974     576
# 7  3122       6      3  1980       530    8.2   330000.0      1269    1257
# 8  3732       4      0  1980      1346    6.8   101000.0      1606    1402
# 9  4401       6      3  1980      1755    7.0    10000.0      2011     280
#
#    star  country    budget      gross  company  runtime  released_year
# 0   699       46  19000000   46998772     1426    146.0              0
# ...

# %%
# High correlation matrix between budget vs gross

correlation_matrix = df2_numerized.corr(method = "pearson")
sns.heatmap(correlation_matrix, annot = True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
df2_numerized.corr()
# Out:
#                    name    rating     genre      year  released     score  \
# name           1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating        -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre          0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year           0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released      -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score          0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes          0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director       0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer         0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star          -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country       -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget         0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
correlation_matrix = df2_numerized.corr()
corr_pairs = correlation_matrix.unstack()

corr_pairs
# Out:
# name           name             1.000000
#                rating          -0.029234
#                genre            0.010996
#                year             0.025542
#                released        -0.006152
#                score            0.014450
#                votes            0.012615
#                director         0.015246
#                writer           0.012880
#                star            -0.006882
#                country         -0.025490
#                budget           0.023392
#                gross            0.005639
#                company          0.021697
#                runtime          0.010850
#                released_year    0.024136
# rating         name            -0.029234
#                rating           1.000000
#                genre            0.147796
#                year             0.019499
#                released         0.018083
#                score            0.065983
#                votes            0.006031
# ...

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre          budget          -0.368523
# budget         genre           -0.368523
# gross          genre           -0.244101
# genre          gross           -0.244101
# rating         budget          -0.203946
# budget         rating          -0.203946
# rating         gross           -0.181906
# gross          rating          -0.181906
# votes          genre           -0.135990
# genre          votes           -0.135990
# company        rating          -0.092357
# rating         company         -0.092357
# country        released_year   -0.074546
# released_year  country         -0.074546
# year           genre           -0.073167
# genre          year            -0.073167
#                company         -0.071334
# company        genre           -0.071334
# year           country         -0.066748
# country        year            -0.066748
# genre          released_year   -0.061186
# released_year  genre           -0.061186
# genre          runtime         -0.059237
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# votes          gross            0.614751
# gross          votes            0.614751
# budget         gross            0.740247
# gross          budget           0.740247
# released_year  year             0.987770
# year           released_year    0.987770
# name           name             1.000000
# company        company          1.000000
# gross          gross            1.000000
# budget         budget           1.000000
# country        country          1.000000
# star           star             1.000000
# writer         writer           1.000000
# director       director         1.000000
# votes          votes            1.000000
# score          score            1.000000
# released       released         1.000000
# year           year             1.000000
# genre          genre            1.000000
# rating         rating           1.000000
# runtime        runtime          1.000000
# released_year  released_year    1.000000
# dtype: float64
